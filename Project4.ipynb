# %%
import pandas as pd
import numpy

# %%
# primary dataset
prime = pd.read_csv("https://data.cityofnewyork.us/api/views/nwjy-fdec/rows.csv?accessType=DOWNLOAD")
prime.head()
# Out:
#      Borough  Admin District  Geographical District  PE Works Cohort     DBN  \
# 0  Manhattan               1                      1                2  01M015
# 1  Manhattan               1                      1                2  01M019
# 2  Manhattan               1                      1                2  01M020
# 3  Manhattan               1                      1                2  01M034
# 4  Manhattan               1                      1                2  01M063
#
#   School Level   Student Enrollment  Full Time Licensed PE Teachers*  \
# 0    Elementary                 143                              1.0
# 1    Elementary                 237                              1.0
# 2    Elementary                 500                              1.0
# 3           K-8                 363                              1.0
# 4    Elementary                 180                              1.0
#
#    F Status PE Teachers*  Itinerant PE Teachers*  \
# ...

# %%
# secondary data set
sec = pd.read_csv("https://data.cityofnewyork.us/api/views/arzb-yfdv/rows.csv?accessType=DOWNLOAD")
sec.head()
# Out:
#    District Grade Level      Category  \
# 0         1           1  All Students
# 1         1           1         Asian
# 2         1           1         Black
# 3         1           1      Hispanic
# 4         1           1         Other
#
#   Average frequency per week of physical education instruction  \
# 0                                           1.502917
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -
#
#   Average minutes per week of physical education instruction  \
# 0                                           115.7585
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -
#
# ...

# %%
#Data cleaning
#TODO:  remove spaces from end of column headers if any

# %%
# Part A TODO:

# Aggregations on primary dataset
# We want to aggregate by school district and group by school level
# we want to see number of students and number of Full Time PE instructors in each school level bucket
# we will make a new column to calculate teacher-student ratio in each school level
# save as a new dataframe

# %%
# Part B TODO:
# Take dataframe from part A, and further filter/aggregate based on School Level:
# combine High School with Junior High-Intermediate-Middle. Rename bucket to "Older Students"
# combine Early Childhood, Elementary, K-8, and Secondary School. Rename bucket to "Younger Students"
# recalculate number of students and Full Time PE instructors
# recalculate teacher-student ratio in each bucket
# save as a new dataframe

# %%
# Part C TODO:
#Aggregations on secondary dataset
#We want to aggregate by school district and group by school level
# Grade levels 1-8 will be in bucket named "Younger Students"
# grade levels 9-12 will be in bucket named "Older students"
# save as a new dataframe

# %%
# Part D TODO:
# Merge the new dataframes from Part B and Part C
# Data from Part B will be placed in the "All Students" row of the combined dataset
#
